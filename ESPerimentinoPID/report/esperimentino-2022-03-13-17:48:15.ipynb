# %%
timestamp = '2022-03-13-17:48:15'

# %%
from lib.ex import Experiment
x = Experiment(timestamp)
x.display()
# Out:
# # Experiment 2022-03-13-17:48:15
# [Go back](./index.ipynb) to the list of all experiments.
#         This experiment was stared at 2022-03-13-17:48:15.
#         Internal PID parameters (heating element): Kp=0, Ki=0, Kd=0.
#         External PID parameters (ambient): Kp=0.875, Ki=105, Kd=52.5.
#         The user asked to reach 23.4375 °C, using fan.
#         The temperature of the box at t0 was 21.4375 °C, so we're asked to increment by 2.0 °C.
#         The temperature of the heating element at t0 was 23.4375.
#         The experiment finished after 659.721848 seconds [about 11 minutes].
#         We have reached the goal after 359 seconds [0:05:59].
#         We have overheated by 0.4375 °C.
#         The temperature continued to increase for 58 seconds [0:00:58].
#         The overhall penality of this experiment is 399.321484375.
# ## Graph (ambient + heating element)
