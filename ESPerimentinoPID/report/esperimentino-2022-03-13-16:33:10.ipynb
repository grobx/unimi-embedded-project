# %%
timestamp = '2022-03-13-16:33:10'

# %%
from lib.ex import Experiment
x = Experiment(timestamp)
x.display()
# Out:
# # Experiment 2022-03-13-16:33:10
# [Go back](./index.ipynb) to the list of all experiments.
#         This experiment was stared at 2022-03-13-16:33:10.
#         Internal PID parameters (heating element): Kp=0.75, Ki=112, Kd=28.
#         External PID parameters (ambient): Kp=0.875, Ki=210, Kd=52.5.
#         The user asked to reach 24.0 °C, using fan.
#         The temperature of the box at t0 was 22.0 °C, so we're asked to increment by 2.0 °C.
#         The temperature of the heating element at t0 was 27.1875.
#         The experiment finished after 667.72194 seconds [about 11 minutes].
#         We have reached the goal after 367 seconds [0:06:07].
#         We have overheated by 0.375 °C.
#         The temperature continued to increase for 99 seconds [0:01:39].
#         The overhall penality of this experiment is 263.8390625.
# ## Graph (ambient + heating element)
