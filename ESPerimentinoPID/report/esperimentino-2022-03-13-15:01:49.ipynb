# %%
timestamp = '2022-03-13-15:01:49'

# %%
from lib.ex import Experiment
x = Experiment(timestamp)
x.display()
# Out:
# # Experiment 2022-03-13-15:01:49
# [Go back](./index.ipynb) to the list of all experiments.
#         This experiment was stared at 2022-03-13-15:01:49.
#         Internal PID parameters (heating element): Kp=0, Ki=0, Kd=0.
#         External PID parameters (ambient): Kp=0.875, Ki=210, Kd=52.5.
#         The user asked to reach 23.5 °C, using fan.
#         The temperature of the box at t0 was 21.5 °C, so we're asked to increment by 2.0 °C.
#         The temperature of the heating element at t0 was 24.9375.
#         The experiment finished after 644.999997 seconds [about 11 minutes].
#         We have reached the goal after 342 seconds [0:05:42].
#         We have overheated by 0.375 °C.
#         The temperature continued to increase for 53 seconds [0:00:53].
#         The overhall penality of this experiment is 290.8546875.
# ## Graph (ambient + heating element)
