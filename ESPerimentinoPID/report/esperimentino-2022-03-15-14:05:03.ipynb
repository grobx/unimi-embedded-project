# %%
timestamp = '2022-03-15-14:05:03'

# %%
from lib.ex import Experiment
x = Experiment(timestamp)
x.display()
# Out:
# # Experiment 2022-03-15-14:05:03
# [Go back](./index.ipynb) to the list of all experiments.
#         This experiment was stared at 2022-03-15-14:05:03.
#         Internal PID parameters (heating element): Kp=42,5, Ki=0, Kd=0.
#         External PID parameters (ambient): Kp=200, Ki=0, Kd=0.
#         The user asked to reach 24.6875 °C, using fan.
#         The temperature of the box at t0 was 22.6875 °C, so we're asked to increment by 2.0 °C.
#         The temperature of the heating element at t0 was 26.0.
#         The experiment finished after 656.700003 seconds [about 11 minutes].
#         We have reached the goal after 337 seconds [0:05:37].
#         We have overheated by 0.125 °C.
#         The temperature continued to increase for 39 seconds [0:00:39].
#         The overhall penality of this experiment is 55.525390625.
# ## Graph (ambient + heating element)
