# %%
timestamp = '2022-03-15-16:54:49'

# %%
from lib.ex import Experiment
x = Experiment(timestamp)
x.display()
# Out:
# # Experiment 2022-03-15-16:54:49
# [Go back](./index.ipynb) to the list of all experiments.
#         This experiment was stared at 2022-03-15-16:54:49.
#         Internal PID parameters (heating element): Kp=25.5, Ki=1, Kd=0.
#         External PID parameters (ambient): Kp=300, Ki=0, Kd=80.
#         The user asked to reach 24.25 °C, using fan.
#         The temperature of the box at t0 was 22.25 °C, so we're asked to increment by 2.0 °C.
#         The temperature of the heating element at t0 was 24.9375.
#         The experiment finished after 676.420884 seconds [about 11 minutes].
#         We have reached the goal after 355 seconds [0:05:55].
#         We have overheated by 0.125 °C.
#         The temperature continued to increase for 151 seconds [0:02:31].
#         The overhall penality of this experiment is 30.012500000000003.
# ## Graph (ambient + heating element)
