# %%
timestamp = '2022-03-13-16:09:22'

# %%
from lib.ex import Experiment
x = Experiment(timestamp)
x.display()
# Out:
# # Experiment 2022-03-13-16:09:22
# [Go back](./index.ipynb) to the list of all experiments.
#         This experiment was stared at 2022-03-13-16:09:22.
#         Internal PID parameters (heating element): Kp=0.875, Ki=210, Kd=52.5.
#         External PID parameters (ambient): Kp=0.875, Ki=210, Kd=52.5.
#         The user asked to reach 23.375 °C, using fan.
#         The temperature of the box at t0 was 21.375 °C, so we're asked to increment by 2.0 °C.
#         The temperature of the heating element at t0 was 23.5.
#         The experiment finished after 675.500021 seconds [about 11 minutes].
#         We have reached the goal after 372 seconds [0:06:12].
#         We have overheated by 0.4375 °C.
#         The temperature continued to increase for 143 seconds [0:02:23].
#         The overhall penality of this experiment is 375.18984375.
# ## Graph (ambient + heating element)
