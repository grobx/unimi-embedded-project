# %%
timestamp = '2022-03-13-01:41:20'

# %%
from lib.ex import Experiment
x = Experiment(timestamp)
x.display()
# Out:
# # Experiment 2022-03-13-01:41:20
# [Go back](./index.ipynb) to the list of all experiments.
#         This experiment was stared at 2022-03-13-01:41:20.
#         Internal PID parameters (heating element): Kp=100, Ki=1, Kd=50.
#         External PID parameters (ambient): Kp=200, Ki=1, Kd=1.
#         The user asked to reach 23.125 °C, using fan.
#         The temperature of the box at t0 was 21.125 °C, so we're asked to increment by 2.0 °C.
#         The temperature of the heating element at t0 was 23.625.
#         The experiment finished after 621.400063 seconds [about 10 minutes].
#         We have reached the goal after 320 seconds [0:05:20].
#         We have overheated by 0.5 °C.
#         The temperature continued to increase for 108 seconds [0:01:48].
#         The overhall penality of this experiment is 514.2625.
# ## Graph (ambient + heating element)
