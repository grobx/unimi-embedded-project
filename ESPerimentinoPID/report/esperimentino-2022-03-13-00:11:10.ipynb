# %%
timestamp = '2022-03-13-00:11:10'

# %%
from lib.ex import Experiment
x = Experiment(timestamp)
x.display()
# Out:
# # Experiment 2022-03-13-00:11:10
# [Go back](./index.ipynb) to the list of all experiments.
#         This experiment was stared at 2022-03-13-00:11:10.
#         Internal PID parameters (heating element): Kp=100, Ki=1, Kd=50.
#         External PID parameters (ambient): Kp=200, Ki=1, Kd=1.
#         The user asked to reach 23.0 °C, using fan.
#         The temperature of the box at t0 was 21.0 °C, so we're asked to increment by 2.0 °C.
#         The temperature of the heating element at t0 was 24.9375.
#         The experiment finished after 598.300012 seconds [about 10 minutes].
#         We have reached the goal after 296 seconds [0:04:56].
#         We have overheated by 0.5625 °C.
#         The temperature continued to increase for 155 seconds [0:02:35].
#         The overhall penality of this experiment is 591.60859375.
# ## Graph (ambient + heating element)
