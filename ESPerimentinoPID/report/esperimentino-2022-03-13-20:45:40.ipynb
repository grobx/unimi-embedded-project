# %%
timestamp = '2022-03-13-20:45:40'

# %%
from lib.ex import Experiment
x = Experiment(timestamp)
x.display()
# Out:
# # Experiment 2022-03-13-20:45:40
# [Go back](./index.ipynb) to the list of all experiments.
#         This experiment was stared at 2022-03-13-20:45:40.
#         Internal PID parameters (heating element): Kp=0, Ki=0, Kd=0.
#         External PID parameters (ambient): Kp=100, Ki=0, Kd=0.
#         The user asked to reach 23.4375 °C, using fan.
#         The temperature of the box at t0 was 21.4375 °C, so we're asked to increment by 2.0 °C.
#         The temperature of the heating element at t0 was 28.0625.
#         The experiment finished after 691.499997 seconds [about 12 minutes].
#         We have reached the goal after 387 seconds [0:06:27].
#         We have overheated by 0.0625 °C.
#         The temperature continued to increase for 9 seconds [0:00:09].
#         The overhall penality of this experiment is 79.059375.
# ## Graph (ambient + heating element)
