# %%
timestamp = '2022-03-12-19:59:43'

# %%
from lib.ex import Experiment
x = Experiment(timestamp)
x.display()
# Out:
# # Experiment 2022-03-12-19:59:43
# [Go back](./index.ipynb) to the list of all experiments.
#         This experiment was stared at 2022-03-12-19:59:43.
#         Internal PID parameters (heating element): Kp=100, Ki=1, Kd=50.
#         External PID parameters (ambient): Kp=200, Ki=1, Kd=1.
#         The user asked to reach 23.0 °C, using fan.
#         The temperature of the box at t0 was 21.0 °C, so we're asked to increment by 2.0 °C.
#         The temperature of the heating element at t0 was 22.625.
#         The experiment finished after 636.853055 seconds [about 11 minutes].
#         We have reached the goal after 323 seconds [0:05:23].
#         We have overheated by 0.4375 °C.
#         The temperature continued to increase for 92 seconds [0:01:32].
#         The overhall penality of this experiment is 387.99765625.
# ## Graph (ambient + heating element)
