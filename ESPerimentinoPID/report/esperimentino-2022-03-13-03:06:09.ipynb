# %%
timestamp = '2022-03-13-03:06:09'

# %%
from lib.ex import Experiment
x = Experiment(timestamp)
x.display()
# Out:
# # Experiment 2022-03-13-03:06:09
# [Go back](./index.ipynb) to the list of all experiments.
#         This experiment was stared at 2022-03-13-03:06:09.
#         Internal PID parameters (heating element): Kp=1, Ki=1, Kd=1.
#         External PID parameters (ambient): Kp=1, Ki=1, Kd=1.
#         The user asked to reach 22.9375 °C, using fan.
#         The temperature of the box at t0 was 20.9375 °C, so we're asked to increment by 2.0 °C.
#         The temperature of the heating element at t0 was 23.375.
#         The experiment finished after 663.399985 seconds [about 11 minutes].
#         We have reached the goal after 361 seconds [0:06:01].
#         We have overheated by 0.75 °C.
#         The temperature continued to increase for 132 seconds [0:02:12].
#         The overhall penality of this experiment is 1154.6234375.
# ## Graph (ambient + heating element)
