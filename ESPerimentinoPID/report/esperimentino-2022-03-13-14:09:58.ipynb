# %%
timestamp = '2022-03-13-14:09:58'

# %%
from lib.ex import Experiment
x = Experiment(timestamp)
x.display()
# Out:
# # Experiment 2022-03-13-14:09:58
# [Go back](./index.ipynb) to the list of all experiments.
#         This experiment was stared at 2022-03-13-14:09:58.
#         Internal PID parameters (heating element): Kp=0, Ki=0, Kd=0.
#         External PID parameters (ambient): Kp=0, Ki=0, Kd=0.
#         The user asked to reach 22.6875 °C, using fan.
#         The temperature of the box at t0 was 20.6875 °C, so we're asked to increment by 2.0 °C.
#         The temperature of the heating element at t0 was 22.4375.
#         The experiment finished after 633.199969 seconds [about 11 minutes].
#         We have reached the goal after 325 seconds [0:05:25].
#         We have overheated by 0.4375 °C.
#         The temperature continued to increase for 103 seconds [0:01:43].
#         The overhall penality of this experiment is 396.46484375.
# ## Graph (ambient + heating element)
