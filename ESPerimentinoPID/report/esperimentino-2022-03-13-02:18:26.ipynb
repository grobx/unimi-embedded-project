# %%
timestamp = '2022-03-13-02:18:26'

# %%
from lib.ex import Experiment
x = Experiment(timestamp)
x.display()
# Out:
# # Experiment 2022-03-13-02:18:26
# [Go back](./index.ipynb) to the list of all experiments.
#         This experiment was stared at 2022-03-13-02:18:26.
#         Internal PID parameters (heating element): Kp=100, Ki=1, Kd=50.
#         External PID parameters (ambient): Kp=200, Ki=1, Kd=1.
#         The user asked to reach 23.375 °C, using fan.
#         The temperature of the box at t0 was 21.375 °C, so we're asked to increment by 2.0 °C.
#         The temperature of the heating element at t0 was 26.5.
#         The experiment finished after 638.099976 seconds [about 11 minutes].
#         We have reached the goal after 332 seconds [0:05:32].
#         We have overheated by 0.5 °C.
#         The temperature continued to increase for 150 seconds [0:02:30].
#         The overhall penality of this experiment is 508.1125.
# ## Graph (ambient + heating element)
