# %%
timestamp = '2022-03-15-13:40:20'

# %%
from lib.ex import Experiment
x = Experiment(timestamp)
#x.result()
x.display()
# Out:
# # Experiment 2022-03-15-13:40:20
# [Go back](./index.ipynb) to the list of all experiments.
#         This experiment was stared at 2022-03-15-13:40:20.
#         Internal PID parameters (heating element): Kp=36.5, Ki=0, Kd=0.
#         External PID parameters (ambient): Kp=200, Ki=0, Kd=0.
#         The user asked to reach 24.6875 °C, using fan.
#         The temperature of the box at t0 was 22.6875 °C, so we're asked to increment by 2.0 °C.
#         The temperature of the heating element at t0 was 25.8125.
#         The experiment finished after 758.50003 seconds [about 13 minutes].
#         We have reached the goal after 382 seconds [0:06:22].
#         We have overheated by 0.0625 °C.
#         The temperature continued to increase for 53 seconds [0:00:53].
#         The overhall penality of this experiment is 103.99531250000001.
# ## Graph (ambient + heating element)
