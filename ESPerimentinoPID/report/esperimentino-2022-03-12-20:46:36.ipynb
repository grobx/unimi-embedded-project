# %%
timestamp = '2022-03-12-20:46:36'

# %%
from lib.ex import Experiment
x = Experiment(timestamp)
x.display()
# Out:
# # Experiment 2022-03-12-20:46:36
# [Go back](./index.ipynb) to the list of all experiments.
#         This experiment was stared at 2022-03-12-20:46:36.
#         Internal PID parameters (heating element): Kp=100, Ki=1, Kd=50.
#         External PID parameters (ambient): Kp=200, Ki=1, Kd=1.
#         The user asked to reach 23.1875 °C, using fan.
#         The temperature of the box at t0 was 21.125 °C, so we're asked to increment by 2.0625 °C.
#         The temperature of the heating element at t0 was 23.375.
#         The experiment finished after 620.353021 seconds [about 10 minutes].
#         We have reached the goal after 318 seconds [0:05:18].
#         We have overheated by 0.5625 °C.
#         The temperature continued to increase for 175 seconds [0:02:55].
#         The overhall penality of this experiment is 611.6857599431818.
# ## Graph (ambient + heating element)
