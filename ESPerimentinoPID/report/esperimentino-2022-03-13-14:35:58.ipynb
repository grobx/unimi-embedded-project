# %%
timestamp = '2022-03-13-14:35:58'

# %%
from lib.ex import Experiment
x = Experiment(timestamp)
x.display()
# Out:
# # Experiment 2022-03-13-14:35:58
# [Go back](./index.ipynb) to the list of all experiments.
#         This experiment was stared at 2022-03-13-14:35:58.
#         Internal PID parameters (heating element): Kp=0.875, Ki=210, Kd=52.5.
#         External PID parameters (ambient): Kp=0, Ki=0, Kd=0.
#         The user asked to reach 23.0625 °C, using fan.
#         The temperature of the box at t0 was 21.0625 °C, so we're asked to increment by 2.0 °C.
#         The temperature of the heating element at t0 was 25.1875.
#         The experiment finished after 627.499993 seconds [about 10 minutes].
#         We have reached the goal after 313 seconds [0:05:13].
#         We have overheated by 0.4375 °C.
#         The temperature continued to increase for 105 seconds [0:01:45].
#         The overhall penality of this experiment is 402.75546875.
# ## Graph (ambient + heating element)
