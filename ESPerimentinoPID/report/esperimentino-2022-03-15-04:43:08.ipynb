# %%
timestamp = '2022-03-15-04:43:08'

# %%
from lib.ex import Experiment
x = Experiment(timestamp)
x.display()
# Out:
# # Experiment 2022-03-15-04:43:08
# [Go back](./index.ipynb) to the list of all experiments.
#         This experiment was stared at 2022-03-15-04:43:08.
#         Internal PID parameters (heating element): Kp=0, Ki=0, Kd=0.
#         External PID parameters (ambient): Kp=200, Ki=0, Kd=160.
#         The user asked to reach 24.0 °C, using fan.
#         The temperature of the box at t0 was 22.0 °C, so we're asked to increment by 2.0 °C.
#         The temperature of the heating element at t0 was 26.5.
#         The experiment finished after 697.936967 seconds [about 12 minutes].
#         We have reached the goal after 372 seconds [0:06:12].
#         We have overheated by 0.0625 °C.
#         The temperature continued to increase for 11 seconds [0:00:11].
#         The overhall penality of this experiment is 99.195703125.
# ## Graph (ambient + heating element)
