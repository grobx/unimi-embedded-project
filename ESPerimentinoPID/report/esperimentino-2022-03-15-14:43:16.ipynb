# %%
timestamp = '2022-03-15-14:43:16'

# %%
from lib.ex import Experiment
x = Experiment(timestamp)
x.display()
# Out:
# # Experiment 2022-03-15-14:43:16
# [Go back](./index.ipynb) to the list of all experiments.
#         This experiment was stared at 2022-03-15-14:43:16.
#         Internal PID parameters (heating element): Kp=36.5, Ki=0, Kd=0.
#         External PID parameters (ambient): Kp=200, Ki=0, Kd=160.
#         The user asked to reach 24.25 °C, using fan.
#         The temperature of the box at t0 was 22.25 °C, so we're asked to increment by 2.0 °C.
#         The temperature of the heating element at t0 was 24.9375.
#         The experiment finished after 671.600056 seconds [about 11 minutes].
#         We have reached the goal after 345 seconds [0:05:45].
#         We have overheated by 0.1875 °C.
#         The temperature continued to increase for 142 seconds [0:02:22].
#         The overhall penality of this experiment is 46.88671875.
# ## Graph (ambient + heating element)
