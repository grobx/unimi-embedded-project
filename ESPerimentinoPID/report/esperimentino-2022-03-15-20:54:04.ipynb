# %%
timestamp = '2022-03-15-20:54:04'

# %%
from lib.ex import Experiment
x = Experiment(timestamp)
x.display()
# Out:
# # Experiment 2022-03-15-20:54:04
# [Go back](./index.ipynb) to the list of all experiments.
#         This experiment was stared at 2022-03-15-20:54:04.
#         Internal PID parameters (heating element): Kp=25.5, Ki=1, Kd=0.
#         External PID parameters (ambient): Kp=960, Ki=0, Kd=80.
#         The user asked to reach 23.125 °C, without using fan.
#         The temperature of the box at t0 was 22.125 °C, so we're asked to increment by 1.0 °C.
#         The temperature of the heating element at t0 was 24.875.
#         The experiment finished after 1301.336962 seconds [about 22 minutes].
#         We have reached the goal after 900 seconds [0:15:00].
#         We have overheated by 0.0625 °C.
#         The temperature continued to increase for 124 seconds [0:02:04].
#         The overhall penality of this experiment is 94.496484375.
# ## Graph (ambient + heating element)
